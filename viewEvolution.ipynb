# %%
# from Evolution import Evolution
import pickle

# %% [markdown]
# ## Load evolution

# %%
env = Evolution()
with open('models/evolution.env', 'rb') as infile:
    env = pickle.load(infile)
myNetwork = env.getNetwork()

# %% [markdown]
# ### Plot Scholar Network

# %%
myNetwork.plotPyvisGraph(filename='pyvis.html')
# Out:
# [8, 9, 10, 11, 2, 4, 5, 13, 17, 18, 0, 1, 19, 20]
# [2, 4, 5, 0, 1]
# [0, 1]
# [0, 1]
# [0, 1]
# [8, 9, 10, 11, 2, 4, 5, 17, 18, 14, 20]
# [2, 4, 5, 3, 6, 14]
# [3, 6, 14]
# [3, 6, 14]
# [3, 6, 14]
# [7, 8, 9, 10, 11, 5, 13, 19]
# [5]
# [6, 14]
# [14]
# [6, 14]
# [6, 14]
# [6, 14, 15]
# [7, 8, 9, 12, 13, 17, 18, 16, 19]
# [16]
# [16]
# [9, 10, 11, 17, 18, 19]
# [11, 17, 18, 19]
# [12]
# [14]
# [14]
# [14]
# [14]
# [14]
# [19]
# [20]

# %%
env.network.plotNetwork()
