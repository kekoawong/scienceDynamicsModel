# %%
from modules.Evolution import Evolution
import pickle

# %% [markdown]
# ## Load evolution

# %%
env = Evolution()
with open('outputs/evolution.env', 'rb') as infile:
    env = pickle.load(infile)
myNetwork = env.getNetwork()

# %% [markdown]
# ### Plot Scholar Network

# %%
# myNetwork.plotPyvisGraph(filename='outputs/pyvis.html', notebook=True)
fig, axs = env.plotDegreeDistr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qp/kbk93qxn41s488wn8qj4p7mm0000gn/T/ipykernel_12707/372656092.py in <module>
#       1 # myNetwork.plotPyvisGraph(filename='outputs/pyvis.html', notebook=True)
# ----> 2 fig, axs = env.plotDegreeDistr()
#
# ~/code/scienceDynamicsModel/modules/Evolution.py in plotDegreeDistr(self, label, ylogBase, xlogBase, ylim, xlim, saveToFile)
#     317     def plotDegreeDistr(self, label='Degree', ylogBase=10, xlogBase=10, ylim=10**-6, xlim=10**4, saveToFile=None):
#     318         distrib = self.getDegreeDistribution()
# --> 319         return self.plotDistibution(distrib, label=label, ylogBase=ylogBase, xlogBase=xlogBase, ylim=ylim, xlim=xlim, saveToFile=saveToFile)
#     320
# ...

# %%
fig, axs = env.plotDescriptorsDistr()
