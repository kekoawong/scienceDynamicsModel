# %%
from Evolution import Evolution

# %%
env = Evolution()
env.evolve(timeSteps=20)

# %%
env.plotNetwork()

# %%
env.evolve(timeSteps=20)
env.plotNetwork()

# %%
print(env)
# Out:
# Evolution network with a total of 23 authors, 41 papers, and 8 disciplines/topics.
#    Author 0 primary disciplines: [7]
#       Paper 3 with the topics [1, 2, 3, 4, 5, 6, 7]
#       Paper 8 with the topics [1, 2, 3, 4, 7]
#       Paper 1 with the topics [2, 3, 4, 7]
#       Paper 3 with the topics [1, 2, 3, 4, 5, 6, 7]
#       Paper 6 with the topics [2, 3, 4, 7]
#       Paper 8 with the topics [1, 2, 3, 4, 7]
#       Paper 1 with the topics [2, 3, 4, 7]
#       Paper 3 with the topics [1, 2, 3, 4, 5, 6, 7]
#       Paper 6 with the topics [2, 3, 4, 7]
#       Paper 8 with the topics [1, 2, 3, 4, 7]
#       Paper 18 with the topics [3, 4, 7]
#       Paper 1 with the topics [2, 3, 4, 7]
#       Paper 3 with the topics [1, 2, 3, 4, 5, 6, 7]
#       Paper 6 with the topics [2, 3, 4, 7]
#       Paper 8 with the topics [1, 2, 3, 4, 7]
#       Paper 18 with the topics [3, 4, 7]
#       Paper 25 with the topics [4, 6, 7]
#       Paper 3 with the topics [1, 2, 3, 4, 5, 6, 7]
# ...
